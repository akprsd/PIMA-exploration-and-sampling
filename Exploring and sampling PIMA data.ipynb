# %%
import pandas as pd
import numpy as nm

# %%
df = pd.read_csv ("/Users/akanksha/Documents/study/Reva/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# 17             7      107             74              0        0  29.6
# 18             1      103             30             38       83  43.3
# 19             1      115             70             30       96  34.6
# 20             3      126             88             41      235  39.3
# 21             8       99             84              0        0  35.4
# 22             7      196             90              0        0  39.8
# 23             9      119             80             35        0  29.0
# 24            11      143             94             33      146  36.6
# 25            10      125             70             26      115  31.1
# 26             7      147             76              0        0  39.4
# 27             1       97             66             15      140  23.2
# 28            13      145             82             19      110  22.2
# 29             5      117             92              0        0  34.1
# ..           ...      ...            ...            ...      ...   ...
# 738            2       99             60             17      160  36.6
# 739            1      102             74              0        0  39.5
# 740           11      120             80             37      150  42.3
# 741            3      102             44             20       94  30.8
# 742            1      109             58             18      116  28.5
# 743            9      140             94              0        0  32.7
# 744           13      153             88             37      140  40.6
# 745           12      100             84             33      105  30.0
# 746            1      147             94             41        0  49.3
# 747            1       81             74             41       57  46.3
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# 5                       0.201   30        0
# 6                       0.248   26        1
# 7                       0.134   29        0
# 8                       0.158   53        1
# 9                       0.232   54        1
# 10                      0.191   30        0
# 11                      0.537   34        1
# 12                      1.441   57        0
# 13                      0.398   59        1
# 14                      0.587   51        1
# 15                      0.484   32        1
# 16                      0.551   31        1
# 17                      0.254   31        1
# 18                      0.183   33        0
# 19                      0.529   32        1
# 20                      0.704   27        0
# 21                      0.388   50        0
# 22                      0.451   41        1
# 23                      0.263   29        1
# 24                      0.254   51        1
# 25                      0.205   41        1
# 26                      0.257   43        1
# 27                      0.487   22        0
# 28                      0.245   57        0
# 29                      0.337   38        0
# ..                        ...  ...      ...
# 738                     0.453   21        0
# 739                     0.293   42        1
# 740                     0.785   48        1
# 741                     0.400   26        0
# 742                     0.219   22        0
# 743                     0.734   45        1
# 744                     1.174   39        0
# 745                     0.488   46        0
# 746                     0.358   27        1
# 747                     1.096   32        0
# 748                     0.408   36        1
# 749                     0.178   50        1
# 750                     1.182   22        1
# 751                     0.261   28        0
# 752                     0.223   25        0
# 753                     0.222   26        1
# 754                     0.443   45        1
# 755                     1.057   37        1
# 756                     0.391   39        0
# 757                     0.258   52        1
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.head ()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail ()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe ()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
# Univariate data for understanding the tables

# %%
import matplotlib.pyplot as plt

x = df['Outcome']

plt.hist(x)
plt.xlabel ('Number of diabetic and non-diabetic samples')
# Out:
# Text(0.5,0,'Number of diabetic and non-diabetic samples')

# %%
x = df['Age']
plt.hist(x)
plt.xlabel ('total age')
# Out:
# Text(0.5,0,'total age')

# %%
# outcome and age

# %%
group_by_age = df.groupby(['Age','Outcome'])

# %%
group_by_age

# %%
#bivariate to understand the correlation

# %%
x = df['Age']
y = df ['Pregnancies']

plt.bar (x,y)

plt.xlabel ('Age')
plt.ylabel ('Pregnancies')
# Out:
# Text(0,0.5,'Pregnancies')

# %%
x= df['BMI']
y= df['Outcome']

plt.scatter (x,y)

plt.xlabel ('BMI')
plt.ylabel ('Outcome')
# Out:
# Text(0,0.5,'Outcome')

# %%
x= df['SkinThickness']
y= df['Insulin']

plt.scatter (x,y)

plt.xlabel ('SkinThickness')
plt.ylabel ('Insulin')
# Out:
# Text(0,0.5,'Insulin')

# %%
x= df['Insulin']
y= df['SkinThickness']

plt.bar (x,y)

plt.xlabel ('Insulin')
plt.ylabel ('SkinThickness')
# Out:
# Text(0,0.5,'SkinThickness')

# %%
x= df['Age']
y= df['Outcome']

plt.scatter (x,y)

plt.xlabel ('Age')
plt.ylabel ('Outcome')
# Out:
# Text(0,0.5,'Outcome')

# %%
x= df['DiabetesPedigreeFunction']
y= df['Outcome']

plt.bar (x,y)

plt.xlabel ('DiabetesPedigreeFunction')
plt.ylabel ('Outcome')
# Out:
# Text(0,0.5,'Outcome')

# %%
# colour based exploration for relation

# %%
x= df['DiabetesPedigreeFunction']
y= df['Age']
z = df ['Outcome']
colors = {int(1):'red',int(0):'green'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('DPF vs Age')
plt.xlabel ('DiabetesPedigreeFunction')
plt.ylabel ('Age')
# Out:
# Text(0,0.5,'Age')

# %%
x= df['DiabetesPedigreeFunction']
y= df['Glucose']
z = df ['Outcome']
colors = {int(1):'red',int(0):'green'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('DPF vs Glucose')
plt.xlabel ('DiabetesPedigreeFunction')
plt.ylabel ('Glucose')
# Out:
# Text(0,0.5,'Glucose')

# %%
x= df['DiabetesPedigreeFunction']
y= df['Age']
z = df ['Outcome']

plt.plot (x,y,z)

plt.title ('DPF vs Age')
plt.xlabel ('DiabetesPedigreeFunction')
plt.ylabel ('Age')
# Out:
# Text(0,0.5,'Age')

# %%
x= df['BMI']
y= df['Age']
z = df ['Outcome']
colors = {int(1):'red',int(0):'blue'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('BMI vs Age')
plt.xlabel ('BMI')
plt.ylabel ('Age')
# Out:
# Text(0,0.5,'Age')

# %%
x= df['BMI']
y= df['Glucose']
z = df ['Outcome']
colors = {int(1):'yellow',int(0):'blue'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('Glucose vs BMI')
plt.xlabel ('BMI')
plt.ylabel ('Glucose')
# Out:
# Text(0,0.5,'Glucose')

# %%
x= df['BloodPressure']
y= df['Glucose']
z = df ['Outcome']
colors = {int(1):'yellow',int(0):'blue'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('Glucose vs BP')
plt.xlabel ('BP')
plt.ylabel ('Glucose')
# Out:
# Text(0,0.5,'Glucose')

# %%
#find the outlier
df.plot.box ()

# %%
#try seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(df, hue="Outcome", size=5) \
   .map(plt.scatter, "Age", "BMI") \
   .add_legend()

# %%
sns.jointplot(x="Glucose", y="Insulin", data=df, size=5)
plt.show()

# %%
sns.jointplot(x="Age", y="DiabetesPedigreeFunction", data=df, size=5)
plt.show()

# %%
#try sns and various tools

# %%
sns.pairplot(df, hue="Outcome", size=3)
plt.show()

# %%
# training/testing samples
import numpy as np

train, test = np.split(df.sample(frac=1), [int(.7*len(df))])

# %%
train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 205            5      111             72             28        0  23.9
# 639            1      100             74             12       46  19.5
# 183            5       73             60              0        0  26.8
# 381            0      105             68             22        0  20.0
# 572            3      111             58             31       44  29.5
# 241            4       91             70             32       88  33.1
# 236            7      181             84             21      192  35.9
# 411            1      112             72             30      176  34.4
# 42             7      106             92             18        0  22.7
# 237            0      179             90             27        0  44.1
# 65             5       99             74             27        0  29.0
# 525            3       87             60             18        0  21.8
# 684            5      136             82              0        0   0.0
# 458           10      148             84             48      237  37.6
# 449            0      120             74             18       63  30.5
# 465            0      124             56             13      105  21.8
# 370            3      173             82             48      465  38.4
# 410            6      102             90             39        0  35.7
# 136            0      100             70             26       50  30.8
# 208            1       96             64             27       87  33.2
# 662            8      167            106             46      231  37.6
# 247            0      165             90             33      680  52.3
# 48             7      103             66             32        0  39.1
# 133            8       84             74             31        0  38.3
# 553            1       88             62             24       44  29.9
# 717           10       94             72             18        0  23.1
# 412            1      143             84             23      310  42.4
# 759            6      190             92              0        0  35.5
# 185            7      194             68             28        0  35.9
# 710            3      158             64             13      387  31.2
# ..           ...      ...            ...            ...      ...   ...
# 162            0      114             80             34      285  44.2
# 155            7      152             88             44        0  50.0
# 319            6      194             78              0        0  23.5
# 246           10      122             68              0        0  31.2
# 20             3      126             88             41      235  39.3
# 69             4      146             85             27      100  28.9
# 667           10      111             70             27        0  27.5
# 656            2      101             58             35       90  21.8
# 199            4      148             60             27      318  30.9
# 431            3       89             74             16       85  30.4
# 211            0      147             85             54        0  42.8
# 748            3      187             70             22      200  36.4
# 529            0      111             65              0        0  24.6
# 446            1      100             72             12       70  25.3
# 487            0      173             78             32      265  46.5
# 345            8      126             88             36      108  38.5
# 619            0      119              0              0        0  32.4
# 8              2      197             70             45      543  30.5
# 95             6      144             72             27      228  33.9
# 402            5      136             84             41       88  35.0
# 312            2      155             74             17       96  26.6
# 281           10      129             76             28      122  35.9
# 550            1      116             70             28        0  27.4
# 177            0      129            110             46      130  67.1
# 479            4      132             86             31        0  28.0
# 91             4      123             80             15      176  32.0
# 256            3      111             56             39        0  30.1
# 126            3      120             70             30      135  42.9
# 212            7      179             95             31        0  34.2
# 250            9      106             52              0        0  31.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 205                     0.407   27        0
# 639                     0.149   28        0
# 183                     0.268   27        0
# 381                     0.236   22        0
# 572                     0.430   22        0
# 241                     0.446   22        0
# 236                     0.586   51        1
# 411                     0.528   25        0
# 42                      0.235   48        0
# 237                     0.686   23        1
# 65                      0.203   32        0
# 525                     0.444   21        0
# 684                     0.640   69        0
# 458                     1.001   51        1
# 449                     0.285   26        0
# 465                     0.452   21        0
# 370                     2.137   25        1
# 410                     0.674   28        0
# 136                     0.597   21        0
# 208                     0.289   21        0
# 662                     0.165   43        1
# 247                     0.427   23        0
# 48                      0.344   31        1
# 133                     0.457   39        0
# 553                     0.422   23        0
# 717                     0.595   56        0
# 412                     1.076   22        0
# 759                     0.278   66        1
# 185                     0.745   41        1
# 710                     0.295   24        0
# ..                        ...  ...      ...
# 162                     0.167   27        0
# 155                     0.337   36        1
# 319                     0.129   59        1
# 246                     0.258   41        0
# 20                      0.704   27        0
# 69                      0.189   27        0
# 667                     0.141   40        1
# 656                     0.155   22        0
# 199                     0.150   29        1
# 431                     0.551   38        0
# 211                     0.375   24        0
# 748                     0.408   36        1
# 529                     0.660   31        0
# 446                     0.658   28        0
# 487                     1.159   58        0
# 345                     0.349   49        0
# 619                     0.141   24        1
# 8                       0.158   53        1
# 95                      0.255   40        0
# 402                     0.286   35        1
# 312                     0.433   27        1
# 281                     0.280   39        0
# 550                     0.204   21        0
# 177                     0.319   26        1
# 479                     0.419   63        0
# 91                      0.443   34        0
# 256                     0.557   30        0
# 126                     0.452   30        0
# 212                     0.164   60        0
# 250                     0.380   42        0
#
# [537 rows x 9 columns]

# %%
test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 323           13      152             90             33       29  26.8
# 424            8      151             78             32      210  42.9
# 580            0      151             90             46        0  42.1
# 363            4      146             78              0        0  38.5
# 705            6       80             80             36        0  39.8
# 286            5      155             84             44      545  38.7
# 131            9      122             56              0        0  33.3
# 604            4      183              0              0        0  28.4
# 649            0      107             60             25        0  26.4
# 593            2       82             52             22      115  28.5
# 352            3       61             82             28        0  34.4
# 533            6       91              0              0        0  29.8
# 740           11      120             80             37      150  42.3
# 720            4       83             86             19        0  29.3
# 704            4      110             76             20      100  28.4
# 659            3       80             82             31       70  34.2
# 505           10       75             82              0        0  33.3
# 578           10      133             68              0        0  27.0
# 56             7      187             68             39      304  37.7
# 341            1       95             74             21       73  25.9
# 111            8      155             62             26      495  34.0
# 387            8      105            100             36        0  43.3
# 543            4       84             90             23       56  39.5
# 501            3       84             72             32        0  37.2
# 76             7       62             78              0        0  32.6
# 546            5      187             76             27      207  43.6
# 504            3       96             78             39        0  37.3
# 403            9       72             78             25        0  31.6
# 144            4      154             62             31      284  32.8
# 158            2       88             74             19       53  29.0
# ..           ...      ...            ...            ...      ...   ...
# 347            3      116              0              0        0  23.5
# 447            0       95             80             45       92  36.5
# 303            5      115             98              0        0  52.9
# 482            4       85             58             22       49  27.8
# 198            4      109             64             44       99  34.8
# 699            4      118             70              0        0  44.5
# 43             9      171            110             24      240  45.4
# 660           10      162             84              0        0  27.7
# 178            5      143             78              0        0  45.0
# 249            1      111             86             19        0  30.1
# 301            2      144             58             33      135  31.6
# 300            0      167              0              0        0  32.3
# 595            0      188             82             14      185  32.0
# 413            1      143             74             22       61  26.2
# 676            9      156             86              0        0  24.8
# 315            2      112             68             22       94  34.1
# 762            9       89             62              0        0  22.5
# 462            8       74             70             40       49  35.3
# 139            5      105             72             29      325  36.9
# 172            2       87              0             23        0  28.9
# 651            1      117             60             23      106  33.8
# 600            1      108             88             19        0  27.1
# 715            7      187             50             33      392  33.9
# 596            0       67             76              0        0  45.3
# 210            2       81             60             22        0  27.7
# 114            7      160             54             32      175  30.5
# 333           12      106             80              0        0  23.6
# 622            6      183             94              0        0  40.8
# 127            1      118             58             36       94  33.3
# 182            1        0             74             20       23  27.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 323                     0.731   43        1
# 424                     0.516   36        1
# 580                     0.371   21        1
# 363                     0.520   67        1
# 705                     0.177   28        0
# 286                     0.619   34        0
# 131                     1.114   33        1
# 604                     0.212   36        1
# 649                     0.133   23        0
# 593                     1.699   25        0
# 352                     0.243   46        0
# 533                     0.501   31        0
# 740                     0.785   48        1
# 720                     0.317   34        0
# 704                     0.118   27        0
# 659                     1.292   27        1
# 505                     0.263   38        0
# 578                     0.245   36        0
# 56                      0.254   41        1
# 341                     0.673   36        0
# 111                     0.543   46        1
# 387                     0.239   45        1
# 543                     0.159   25        0
# 501                     0.267   28        0
# 76                      0.391   41        0
# 546                     1.034   53        1
# 504                     0.238   40        0
# 403                     0.280   38        0
# 144                     0.237   23        0
# 158                     0.229   22        0
# ..                        ...  ...      ...
# 347                     0.187   23        0
# 447                     0.330   26        0
# 303                     0.209   28        1
# 482                     0.306   28        0
# 198                     0.905   26        1
# 699                     0.904   26        0
# 43                      0.721   54        1
# 660                     0.182   54        0
# 178                     0.190   47        0
# 249                     0.143   23        0
# 301                     0.422   25        1
# 300                     0.839   30        1
# 595                     0.682   22        1
# 413                     0.256   21        0
# 676                     0.230   53        1
# 315                     0.315   26        0
# 762                     0.142   33        0
# 462                     0.705   39        0
# 139                     0.159   28        0
# 172                     0.773   25        0
# 651                     0.466   27        0
# 600                     0.400   24        0
# 715                     0.826   34        1
# 596                     0.194   46        0
# 210                     0.290   25        0
# 114                     0.588   39        1
# 333                     0.137   44        0
# 622                     1.461   45        0
# 127                     0.261   23        0
# 182                     0.299   21        0
#
# [231 rows x 9 columns]

# %%
# explore train data

# %%
train.head ()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 205            5      111             72             28        0  23.9
# 639            1      100             74             12       46  19.5
# 183            5       73             60              0        0  26.8
# 381            0      105             68             22        0  20.0
# 572            3      111             58             31       44  29.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 205                     0.407   27        0
# 639                     0.149   28        0
# 183                     0.268   27        0
# 381                     0.236   22        0
# 572                     0.430   22        0

# %%
train.tail ()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 91             4      123             80             15      176  32.0
# 256            3      111             56             39        0  30.1
# 126            3      120             70             30      135  42.9
# 212            7      179             95             31        0  34.2
# 250            9      106             52              0        0  31.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 91                      0.443   34        0
# 256                     0.557   30        0
# 126                     0.452   30        0
# 212                     0.164   60        0
# 250                     0.380   42        0

# %%
train.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.104692       0.102345      -0.074813
# Glucose                      0.104692  1.000000       0.162223       0.066906
# BloodPressure                0.102345  0.162223       1.000000       0.231080
# SkinThickness               -0.074813  0.066906       0.231080       1.000000
# Insulin                     -0.093135  0.315428       0.113057       0.412339
# BMI                          0.001169  0.260977       0.310575       0.425485
# DiabetesPedigreeFunction    -0.057760  0.139105       0.076941       0.182694
# Age                          0.523071  0.278779       0.205451      -0.091015
# Outcome                      0.215240  0.451460       0.049878       0.057275
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.093135  0.001169                 -0.057760
# Glucose                   0.315428  0.260977                  0.139105
# BloodPressure             0.113057  0.310575                  0.076941
# SkinThickness             0.412339  0.425485                  0.182694
# Insulin                   1.000000  0.203129                  0.130664
# BMI                       0.203129  1.000000                  0.156911
# DiabetesPedigreeFunction  0.130664  0.156911                  1.000000
# Age                      -0.045221  0.028808                  0.050468
# Outcome                   0.123910  0.295428                  0.192182
#
#                                Age   Outcome
# Pregnancies               0.523071  0.215240
# Glucose                   0.278779  0.451460
# BloodPressure             0.205451  0.049878
# SkinThickness            -0.091015  0.057275
# Insulin                  -0.045221  0.123910
# BMI                       0.028808  0.295428
# DiabetesPedigreeFunction  0.050468  0.192182
# Age                       1.000000  0.225204
# Outcome                   0.225204  1.000000

# %%
train.describe ()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   537.000000  537.000000     537.000000     537.000000  537.000000
# mean      3.668529  121.204842      68.821229      21.070764   83.011173
# std       3.368256   31.577536      18.910770      16.032227  115.673998
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000  100.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      70.000000      23.000000   45.000000
# 75%       6.000000  140.000000      78.000000      32.000000  130.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  537.000000                537.000000  537.000000  537.000000
# mean    32.082123                  0.476315   33.068901    0.353818
# std      7.872134                  0.332903   11.734346    0.478599
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.400000                  0.246000   24.000000    0.000000
# 50%     32.400000                  0.380000   29.000000    0.000000
# 75%     36.400000                  0.640000   40.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
import matplotlib.pyplot as plt

x = train['Outcome']

plt.hist(x)
plt.xlabel ('Number of diabetic and non-diabetic samples')
# Out:
# Text(0.5,0,'Number of diabetic and non-diabetic samples')

# %%
x = train['Age']

plt.hist(x)
plt.xlabel ('Age distribuion')
# Out:
# Text(0.5,0,'Age distribuion')

# %%
x = train['BloodPressure']

plt.hist(x)
plt.xlabel ('BloodPressure')
# Out:
# Text(0.5,0,'BloodPressure')

# %%
sns.pairplot(train, hue="Outcome", size=3)
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5) \
   .map(plt.scatter, "Age", "BMI") \

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "DiabetesPedigreeFunction", "BMI")

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "DiabetesPedigreeFunction", "Glucose")

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "BMI", "BloodPressure")

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "SkinThickness", "BloodPressure")

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "Insulin", "BMI")

# %%
pd.pivot_table(train, values="Age", index=["Outcome"], aggfunc = 'count', fill_value=0)
# Out:
#          Age
# Outcome
# 0        347
# 1        190

# %%
test.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 323           13      152             90             33       29  26.8
# 424            8      151             78             32      210  42.9
# 580            0      151             90             46        0  42.1
# 363            4      146             78              0        0  38.5
# 705            6       80             80             36        0  39.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 323                     0.731   43        1
# 424                     0.516   36        1
# 580                     0.371   21        1
# 363                     0.520   67        1
# 705                     0.177   28        0

# %%
test.tail ()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 114            7      160             54             32      175  30.5
# 333           12      106             80              0        0  23.6
# 622            6      183             94              0        0  40.8
# 127            1      118             58             36       94  33.3
# 182            1        0             74             20       23  27.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 114                     0.588   39        1
# 333                     0.137   44        0
# 622                     1.461   45        0
# 127                     0.261   23        0
# 182                     0.299   21        0

# %%
pd.pivot_table(test, values="Age", index=["Outcome"], aggfunc = 'count', fill_value=0)
# Out:
#          Age
# Outcome
# 0        153
# 1         78
