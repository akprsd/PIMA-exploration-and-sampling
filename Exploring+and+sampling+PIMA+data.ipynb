# %%
import pandas as pd
import numpy as nm

# %%
df = pd.read_csv ("C:\\Users\\Public\\Documents\\Python Scripts\\diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
df.head ()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail ()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe ()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.matshow(df.corr())
plt.show()

# %%
# Univariate data for understanding the tables

# %%
import matplotlib.pyplot as plt

x = df['Outcome']

plt.hist(x)
plt.xlabel ('Number of diabetic and non-diabetic samples')
plt.show()

# %%
x = df['Age']
plt.hist(x)
plt.xlabel ('total age')
plt.show()

# %%
# outcome and age

# %%
group_by_age = df.groupby(['Age','Outcome'])

# %%
group_by_age

# %%
#bivariate to understand the correlation

# %%
x = df['Age']
y = df ['Pregnancies']

plt.bar (x,y)

plt.xlabel ('Age')
plt.ylabel ('Pregnancies')
plt.show()

# %%
x= df['BMI']
y= df['Outcome']

plt.scatter (x,y)

plt.xlabel ('BMI')
plt.ylabel ('Outcome')
plt.show()

# %%
x= df['SkinThickness']
y= df['Insulin']

plt.scatter (x,y)

plt.xlabel ('SkinThickness')
plt.ylabel ('Insulin')
plt.show()

# %%
x= df['Insulin']
y= df['SkinThickness']

plt.bar (x,y)

plt.xlabel ('Insulin')
plt.ylabel ('SkinThickness')
plt.show()

# %%
x= df['Age']
y= df['Outcome']

plt.scatter (x,y)

plt.xlabel ('Age')
plt.ylabel ('Outcome')
plt.show()

# %%
x= df['DiabetesPedigreeFunction']
y= df['Outcome']

plt.bar (x,y)

plt.xlabel ('DiabetesPedigreeFunction')
plt.ylabel ('Outcome')
plt.show()

# %%
# colour based exploration for relation

# %%
x= df['DiabetesPedigreeFunction']
y= df['Age']
z = df ['Outcome']
colors = {int(1):'red',int(0):'green'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('DPF vs Age')
plt.xlabel ('DiabetesPedigreeFunction')
plt.ylabel ('Age')
plt.show()

# %%
x= df['DiabetesPedigreeFunction']
y= df['Glucose']
z = df ['Outcome']
colors = {int(1):'red',int(0):'green'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('DPF vs Glucose')
plt.xlabel ('DiabetesPedigreeFunction')
plt.ylabel ('Glucose')
plt.show()

# %%
x= df['BMI']
y= df['Age']
z = df ['Outcome']
colors = {int(1):'red',int(0):'blue'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('BMI vs Age')
plt.xlabel ('BMI')
plt.ylabel ('Age')
plt.show()

# %%
x= df['BMI']
y= df['Glucose']
z = df ['Outcome']
colors = {int(1):'yellow',int(0):'blue'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('Glucose vs BMI')
plt.xlabel ('BMI')
plt.ylabel ('Glucose')
plt.show()

# %%
x= df['BloodPressure']
y= df['Glucose']
z = df ['Outcome']
colors = {int(1):'yellow',int(0):'blue'}
plt.scatter (x,y,c=z.apply(lambda x: colors[x]))
plt.title ('Glucose vs BP')
plt.xlabel ('BP')
plt.ylabel ('Glucose')
plt.show()

# %%
#find the outlier
df.plot.box()
plt.show()

# %%
#try seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(df, hue="Outcome", size=5) \
   .map(plt.scatter, "Age", "BMI") \
   .add_legend()

# %%
sns.jointplot(x="Glucose", y="Insulin", data=df, size=5)
plt.show()

# %%
sns.jointplot(x="Age", y="DiabetesPedigreeFunction", data=df, size=5)
plt.show()

# %%
#try sns and various tools

# %%
sns.pairplot(df, hue="Outcome", size=3)
plt.show()

# %%
# training/testing samples
import numpy as np

train, test = np.split(df.sample(frac=1), [int(.7*len(df))])

# %%
train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 538            0      127             80             37      210  36.3
# 258            1      193             50             16      375  25.9
# 412            1      143             84             23      310  42.4
# 156            2       99             52             15       94  24.6
# 716            3      173             78             39      185  33.8
# 744           13      153             88             37      140  40.6
# 535            4      132              0              0        0  32.9
# 215           12      151             70             40      271  41.8
# 408            8      197             74              0        0  25.9
# 685            2      129             74             26      205  33.2
# 617            2       68             62             13       15  20.1
# 20             3      126             88             41      235  39.3
# ...

# %%
test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 311            0      106             70             37      148  39.4
# 327           10      179             70              0        0  35.1
# 530            2      122             60             18      106  29.8
# 270           10      101             86             37        0  45.6
# 171            6      134             70             23      130  35.4
# 725            4      112             78             40        0  39.4
# 737            8       65             72             23        0  32.0
# 278            5      114             74              0        0  24.9
# 272            3      122             78              0        0  23.0
# 433            2      139             75              0        0  25.6
# 389            3      100             68             23       81  31.6
# 677            0       93             60              0        0  35.3
# ...

# %%
# explore train data

# %%
train.head ()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 538            0      127             80             37      210  36.3
# 258            1      193             50             16      375  25.9
# 412            1      143             84             23      310  42.4
# 156            2       99             52             15       94  24.6
# 716            3      173             78             39      185  33.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 538                     0.804   23        0
# 258                     0.655   24        0
# 412                     1.076   22        0
# 156                     0.637   21        0
# 716                     0.970   31        1

# %%
train.tail ()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 428            0      135             94             46      145  40.6
# 221            2      158             90              0        0  31.6
# 674            8       91             82              0        0  35.6
# 561            0      198             66             32      274  41.3
# 749            6      162             62              0        0  24.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 428                     0.284   26        0
# 221                     0.805   66        1
# 674                     0.587   68        0
# 561                     0.502   28        1
# 749                     0.178   50        1

# %%
train.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.124318       0.167147      -0.087137
# Glucose                      0.124318  1.000000       0.147806       0.050969
# BloodPressure                0.167147  0.147806       1.000000       0.231118
# SkinThickness               -0.087137  0.050969       0.231118       1.000000
# Insulin                     -0.041650  0.340160       0.111176       0.472229
# BMI                          0.020174  0.215355       0.240308       0.372145
# DiabetesPedigreeFunction    -0.051235  0.166371       0.056564       0.211878
# Age                          0.552432  0.248852       0.212791      -0.144847
# Outcome                      0.188381  0.454328       0.051080       0.068369
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.041650  0.020174                 -0.051235
# ...

# %%
train.describe ()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   537.000000  537.000000     537.000000     537.000000  537.000000
# mean      3.852886  119.988827      68.754190      20.210428   74.608939
# std       3.455846   31.940182      19.671631      15.825731  107.738177
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      70.000000      23.000000    0.000000
# 75%       6.000000  140.000000      80.000000      32.000000  120.000000
# max      17.000000  198.000000     114.000000      63.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  537.000000                537.000000  537.000000  537.000000
# mean    32.217877                  0.471898   33.033520    0.351955
# std      7.597443                  0.334527   11.817439    0.478025
# ...

# %%
import matplotlib.pyplot as plt

x = train['Outcome']

plt.hist(x)
plt.xlabel ('Number of diabetic and non-diabetic samples')
plt.show()

# %%
x = train['Age']

plt.hist(x)
plt.xlabel ('Age distribuion')
plt.show()

# %%
x = train['BloodPressure']

plt.hist(x)
plt.xlabel ('BloodPressure')
plt.show()

# %%
sns.pairplot(train, hue="Outcome", size=3)
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5) \
   .map(plt.scatter, "Age", "BMI")
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "DiabetesPedigreeFunction", "BMI")
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "DiabetesPedigreeFunction", "Glucose")
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "BMI", "BloodPressure")
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "SkinThickness", "BloodPressure")
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(train, hue="Outcome", size=5).map(plt.scatter, "Insulin", "BMI")
plt.show()

# %%
pd.pivot_table(train, values="Age", index=["Outcome"], aggfunc = 'count', fill_value=0)
# Out:
# Outcome
# 0    348
# 1    189
# Name: Age, dtype: int64

# %%
test.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 49             7      105              0              0        0   0.0
# 710            3      158             64             13      387  31.2
# 11            10      168             74              0        0  38.0
# 734            2      105             75              0        0  23.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 661                     1.394   22        1
# 49                      0.305   24        0
# 710                     0.295   24        0
# 11                      0.537   34        1
# 734                     0.560   53        0

# %%
test.tail ()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 643            4       90              0              0        0  28.0
# 678            3      121             52              0        0  36.0
# 107            4      144             58             28      140  29.5
# 360            5      189             64             33      325  31.2
# 270           10      101             86             37        0  45.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 643                     0.610   31        0
# 678                     0.127   25        1
# 107                     0.287   37        0
# 360                     0.583   29        1
# 270                     1.136   38        1

# %%
pd.pivot_table(test, values="Age", index=["Outcome"], aggfunc = 'count', fill_value=0)
# Out:
# Outcome
# 0    152
# 1     79
# Name: Age, dtype: int64
